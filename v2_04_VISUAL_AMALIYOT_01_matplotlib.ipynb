# %% [markdown]
# <a href="https://colab.research.google.com/github/sitbayevalibek/data-science-praktikum-amaliyotlar/blob/main/v2_04_VISUAL_AMALIYOT_01_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 1-AMALIYOT. `matplotlib`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Ushbu amaliyot uchun https://en.tutiempo.net/climate/ws-384570.html sahifasidagi Toshkent shahri o'rtacha havo harorati haqidagi ma'lumotlardan foydalanamiz.
#
# ![](https://i.imgur.com/lCIRIYm.png)

# %%
#@title QUYIDAGI KODGA TEGMANG!!! 
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## 1-VAZIFA: Sahifadagi jadvalni pandas dataframega aylantiring va:
# ### - Yil (`Year`) ustunini index sifatida o'qing.
# ### - 1990 yildan avvalgi ma'lumotlar tashlab yuboring.
# ### - natijani `df` degan o'zgaruvchiga saqlang

# %%
# JAVOBNI SHUYERGA YOZING
data = pd.read_html("https://en.tutiempo.net/climate/ws-384570.html", index_col=0)
df = data[3][data[3].index>1990]
df.head()
# Out:
#          T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# Year
# 1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 1994  14.4  21.1  8.0  595.38  5.1  66  28   4   9  0  0
# 1995  15.0  22.2  8.4  189.99  4.4  41  20   8  12  0  0

# %% [markdown]
# ## 2-VAZIFA. Har bir ustun nimani anglatishi ham yuqoridagi sahifada joylashgan. Shu jadvalni ham chiqaring. Matnlarni [Google translate](https://translate.google.com) orqali tarjima qilib, uqib oling.

# %%
# JAVOBNI SHUYERGA YOZING
data = pd.read_html("https://en.tutiempo.net/climate/ws-384570.html", index_col=0)
df1 = data[4]
df1.head()
# Out:
#                                           1
# 0
# T                Average annual temperature
# TM       Annual average maximum temperature
# Tm       Average annual minimum temperature
# PP  Rain or snow precipitation total annual
# V                 Annual average wind speed

# %% [markdown]
# ## 3-VAZIFA. `df`ni tahlil qilamiz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 1991 to 2021
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       31 non-null     object
#  1   TM      31 non-null     object
#  2   Tm      31 non-null     object
#  3   PP      31 non-null     object
#  4   V       31 non-null     object
#  5   RA      31 non-null     object
#  6   SN      31 non-null     object
#  7   TS      31 non-null     object
#  8   FG      31 non-null     object
#  9   TN      31 non-null     object
#  10  GR      31 non-null     object
# dtypes: object(11)
# memory usage: 2.9+ KB

# %% [markdown]
# ### **SAVOL**: Yuqoridagi natijadan qanday xulosaga kelish mumkin? DF dagi sonlar bilan ishlasak bo'ladimi?

# %% [markdown]
# ## 4-VAZIFA. `df`dagi barcha `-` belgilarni `NaN` qiymat bilan almashtiring.

# %%
# JAVOBNI SHUYERGA YOZING
df = df.replace("-", np.nan)
df
# Out:
#          T    TM    Tm      PP     V   RA   SN   TS   FG   TN   GR
# Year
# 1991  14.4  21.2   8.3  460.52   5.1   77   26   15   17    0    1
# 1992  14.4  20.8   8.6  470.39   5.1   93   19    9    2    0    1
# 1993  13.4  19.6   7.6  710.97   5.4   98   38   12   10    1    0
# 1994  14.4  21.1   8.0  595.38   5.1   66   28    4    9    0    0
# 1995  15.0  22.2   8.4  189.99   4.4   41   20    8   12    0    0
# 1996  14.0  20.5   7.6  184.16   5.0   68   23   14   13    0    0
# 1997   NaN   NaN   NaN     NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1998   NaN   NaN   NaN     NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1999  15.7  22.4   8.9  524.21   7.6   98   15   13   18    0    0
# 2000  16.0  22.5   9.1     NaN   8.0   84   19   11   25    0    2
# 2001  16.3  22.7   9.2     NaN   8.2   80   20   12   23    1    0
# 2002   NaN   NaN   NaN     NaN   NaN   92   35   13   28    0    0
# 2003  15.6  21.7   8.9  564.92   7.8  109   22   13   19    0    1
# 2004  16.6  22.8   9.6  410.74   7.7  104   17    7   34    0    0
# 2005   NaN   NaN   NaN     NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2006  16.4  22.6   9.0     NaN   9.1   93   29   21   44    0    0
# 2007  16.2  22.6   8.5     NaN   9.0   86   17   16   37    0    0
# 2008  15.9  22.3   8.4     NaN   8.8   75   34    7   45    0    3
# 2009  16.1  22.3   8.7     NaN   9.0  119   12   22   31    0    1
# 2010  16.8  23.3   9.4     NaN   9.0  109   13   27   27    0    0
# 2011  15.8  21.8   8.6     NaN   9.5  105   41   16   50    0    0
# 2012  15.0  21.4   7.9     NaN   9.4   86   40   23   28    0    2
# 2013  16.3  22.6   9.1     NaN   9.6   90   29   17   22    0    0
# 2014  14.9  21.2   7.8     NaN   9.5   96   30   13   34    0    2
# 2015  16.3  22.3   9.6     NaN   9.9  119   23   19   14    0    0
# 2016  16.8  23.3   9.9     NaN   9.9  102   24   11    6    0    0
# 2017  16.0  22.3   9.0     NaN   9.9   92   27   14   31    0    0
# 2018  16.0  22.4   9.3     NaN   9.7   92   16    9   30    0    0
# 2019  16.6  22.5  10.0     NaN   9.8  111   16   12   19    0    0
# 2020  15.5  21.3   9.2     NaN   9.8   92   37   18   26    0    0
# 2021  17.0  23.4  10.1     NaN  10.0   82   11   10   14    0    0
# 2022  16.7  22.6  10.2     NaN   9.8  115   17   14   32    0    0
# 2023   NaN   NaN   NaN     NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ## 5-VAZIFA. `df` ustunlari qiymatlarini matndan o'nlik songa (`float`) o'zgartiring.

# %%
# JAVOBNI SHUYERGA YOZING
df = df.astype(dtype='float')
df.head()
# Out:
#          T    TM   Tm      PP    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  460.52  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  470.39  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  710.97  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  595.38  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  189.99  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %% [markdown]
# ## 6-VAZIFA. `NaN` qiymatlar bilan ishlaymiz
# ### 6.1. Har bir ustundagi `NaN` qiymatlar soni va ularning proprosiyasini toping.

# %%
# JAVOBNI SHUYERGA YOZING
df.isnull().sum()/len(df)*100
# Out:
# T     15.151515
# TM    15.151515
# Tm    15.151515
# PP    72.727273
# V     15.151515
# RA    12.121212
# SN    12.121212
# TS    12.121212
# FG    12.121212
# TN    12.121212
# GR    12.121212
# dtype: float64

# %% [markdown]
# ### 6.2. Eng ko'p `nan` qiymat mavjud ustunni tashlab yuboring va natijani saqlab qoling.

# %%
# JAVOBNI SHUYERGA YOZING
df.drop('PP', axis=1, inplace=True)
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
df.head(30)
# Out:
#          T    TM    Tm    V     RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2   8.3  5.1   77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8   8.6  5.1   93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6   7.6  5.4   98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1   8.0  5.1   66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2   8.4  4.4   41.0  20.0   8.0  12.0  0.0  0.0
# 1996  14.0  20.5   7.6  5.0   68.0  23.0  14.0  13.0  0.0  0.0
# 1997   NaN   NaN   NaN  NaN    NaN   NaN   NaN   NaN  NaN  NaN
# 1998   NaN   NaN   NaN  NaN    NaN   NaN   NaN   NaN  NaN  NaN
# 1999  15.7  22.4   8.9  7.6   98.0  15.0  13.0  18.0  0.0  0.0
# 2000  16.0  22.5   9.1  8.0   84.0  19.0  11.0  25.0  0.0  2.0
# 2001  16.3  22.7   9.2  8.2   80.0  20.0  12.0  23.0  1.0  0.0
# 2002   NaN   NaN   NaN  NaN   92.0  35.0  13.0  28.0  0.0  0.0
# 2003  15.6  21.7   8.9  7.8  109.0  22.0  13.0  19.0  0.0  1.0
# 2004  16.6  22.8   9.6  7.7  104.0  17.0   7.0  34.0  0.0  0.0
# 2005   NaN   NaN   NaN  NaN    NaN   NaN   NaN   NaN  NaN  NaN
# 2006  16.4  22.6   9.0  9.1   93.0  29.0  21.0  44.0  0.0  0.0
# 2007  16.2  22.6   8.5  9.0   86.0  17.0  16.0  37.0  0.0  0.0
# 2008  15.9  22.3   8.4  8.8   75.0  34.0   7.0  45.0  0.0  3.0
# 2009  16.1  22.3   8.7  9.0  119.0  12.0  22.0  31.0  0.0  1.0
# 2010  16.8  23.3   9.4  9.0  109.0  13.0  27.0  27.0  0.0  0.0
# 2011  15.8  21.8   8.6  9.5  105.0  41.0  16.0  50.0  0.0  0.0
# 2012  15.0  21.4   7.9  9.4   86.0  40.0  23.0  28.0  0.0  2.0
# 2013  16.3  22.6   9.1  9.6   90.0  29.0  17.0  22.0  0.0  0.0
# 2014  14.9  21.2   7.8  9.5   96.0  30.0  13.0  34.0  0.0  2.0
# 2015  16.3  22.3   9.6  9.9  119.0  23.0  19.0  14.0  0.0  0.0
# 2018  16.0  22.4   9.3   9.7   92.0  16.0   9.0  30.0  0.0  0.0
# 2019  16.6  22.5  10.0   9.8  111.0  16.0  12.0  19.0  0.0  0.0
# 2020  15.5  21.3   9.2   9.8   92.0  37.0  18.0  26.0  0.0  0.0
# 2021  17.0  23.4  10.1  10.0   82.0  11.0  10.0  14.0  0.0  0.0
# 2022  16.7  22.6  10.2   9.8  115.0  17.0  14.0  32.0  0.0  0.0
# 2023   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN

# %% [markdown]
# ### 6.4. Yakuniy `df` ni csv faylga saqlab, kompyuterga (yoki githubga) yuklab oling (keyingi darsda ishlatamiz)

# %%
# JAVOBNI SHUYERGA YOZING
df.to_csv("tashtemp.csv")

# %% [markdown]
# ##7-VAZIFA. Chiziqli grafiklar

# %% [markdown]
# ### 7.1. `df`dan yillik o'rtacha haroratni ko'rsatuvchi ustunni `x` o'zgaruvchiga saqlang va `plt.plot()` yordamida chiziqli grafik chizing.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# JAVOBNI SHUYERGA YOZING
x = df['T']
plt.plot(x)
plt.show()

# %% [markdown]
# ### 7.2. Yuqoridagi grafikni hajmini kattalashtiring, chiziq qalingligi, turi, rangi, markerlar turini istalgancha o'zgartiring

# %%
# JAVOBNI SHUYERGA YOZING
plt.figure(figsize=(12,6))
x = df['T']
plt.plot(x, 
        linewidth=1.5,
        linestyle="--",
        color='b',
        marker="o",
        markerfacecolor='r'
        )
plt.legend(['TempChange'], loc=2, fontsize='x-large')
plt.grid(color="tomato", linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# ### 7.3. Yuqoridagi grafikda x va y o'qlarini nomlang, grafikka ham umumiy nom bering

# %%
# JAVOBNI SHUYERGA YOZING
plt.figure(figsize=(12,6))
x = df['T']
plt.plot(x, 
        linewidth=1.5,
        linestyle="--",
        color='b',
        marker="o",
        markerfacecolor='r'
        )
plt.xlabel('Yil')
plt.ylabel('Harorat')
plt.title("Toshkent shahri uchun o'rtacha yillik harorat")
plt.legend(['TempChange'], loc=2, fontsize='x-large')
plt.grid(color="tomato", linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# ## 8-VAZIFA. Toshkent shahri uchun, har bir yilda o'rtacha min va max haroratlarni ko'rsatuvchi grafik chizing. **Grafikni faylga saqlab oling**

# %%
# JAVOBNI SHUYERGA YOZING
plt.figure(figsize=(12,6))
max = df['TM']
min = df['Tm']
plt.plot(max, 
        linewidth=1.5,
        linestyle="--",
        color='orange',
        marker="^",
        markerfacecolor='r'
        )
plt.plot(min, 
        linewidth=1.5,
        linestyle="--",
        color='b',
        marker="v",
        markerfacecolor='y'
        )
plt.xlabel('Yil')
plt.ylabel('Harorat')
plt.title("Toshkent shahri uchun o'rtacha yillik max va min harorat")
plt.legend(['max', 'min'], loc=2, fontsize='x-large')
plt.grid(color="tomato", linestyle="--", alpha=0.5)
plt.show()
plt.savefig("Tash-min-max-temp.png")

# %% [markdown]
# ## 9-VAZIFA. Faylga saqlangan grafikni ochib ko'ring.

# %%
# JAVOBNI SHUYERGA YOZING
from IPython.display import Image
Image("Tash-min-max-temp.png") # Menda negadir bu funksiya ishlamadi
